# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
key = os.environ.get('AZURE_SEARCH_KEY', 'b6d5eb8baebe45a89d4c184265f16da7')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128)>

# %%
def search_images_bing(key, term, max_images: int = 150, **kwargs):    
    params = {'q':term, 'count':max_images}
    headers = {"Ocp-Apim-Subscription-Key":key}
    search_url = "https://api.bing.microsoft.com/v7.0/images/search"
    response = requests.get(search_url, headers=headers, params=params)
    response.raise_for_status()
    search_results = response.json() 
   
    # returns an L object to be identical to the original function.
    return L(search_results['value'])

search_images_bing
# Out:
# <function __main__.search_images_bing(key, term, max_images: int = 150, **kwargs)>

# %%
results = search_images_bing(key, 'red panda')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 150

# %%
ims
# Out:
# (#150) ['https://upload.wikimedia.org/wikipedia/commons/thumb/5/50/RedPandaFullBody.JPG/1200px-RedPandaFullBody.JPG','http://virginiazoo.org/wp-content/uploads/2013/03/red-panda-1-e1480367081955.jpg','https://pixfeeds.com/images/animals/red-pandas/1280-178167661-red-panda.jpg','http://cdn-image.travelandleisure.com/sites/default/files/styles/1600x1000/public/1470413107/Red-Panda-EXP0816.jpg?itok=xmKSVh9T','https://eattravelhappy.files.wordpress.com/2013/01/dsc04487-e.jpg','https://cdn.vox-cdn.com/thumbor/QJMh2N7xuwDRv56pekZ2LcZ8BbM=/0x49:4928x2821/1600x900/cdn.vox-cdn.com/uploads/chorus_image/image/49388585/16071828377_85109fdee4_o.0.0.jpg','http://cdn-image.foodandwine.com/sites/default/files/1496166014/red-pandas-2-FT-BLOG0517.jpg','https://resize.hswstatic.com/w_907/gif/red-panda.jpg','https://peopledotcom.files.wordpress.com/2016/11/red-panda.jpg?w=2000','https://pixfeeds.com/images/animals/red-pandas/1280-136345107-red-panda.jpg'...]

# %%
results
# Out:
# (#150) [{'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&q=grizzly+bear&id=4B18E005DE8D44734820462284B5AE4D56B2DBDF&simid=607988827711078650', 'name': 'Bears: Tips From A Controversial Expert | GearJunkie', 'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.WYa7LLNdotAvnN0wJHsG6gHaGs&pid=Api', 'datePublished': '2015-07-29T18:56:00.0000000Z', 'isFamilyFriendly': True, 'contentUrl': 'http://images.gearjunkie.com/uploads/2015/07/Grizzly-Bear.jpg', 'hostPageUrl': 'https://gearjunkie.com/bears-safety-tips-bear-spray', 'contentSize': '1316280 B', 'encodingFormat': 'jpeg', 'hostPageDisplayUrl': 'https://gearjunkie.com/bears-safety-tips-bear-spray', 'width': 2048, 'height': 1852, 'hostPageFavIconUrl': 'https://www.bing.com/th?id=ODF.P6c9yQaw10pLnuum6sROaw&pid=Api', 'hostPageDomainFriendlyName': 'GearJunkie', 'thumbnail': {'width': 474, 'height': 428}, 'imageInsightsToken': 'ccid_WYa7LLNd*cp_EE29504F398EF209E085D8684A0E61B0*mid_4B18E005DE8D44734820462284B5AE4D56
# ...

# %%
ims = ['https://upload.wikimedia.org/wikipedia/commons/thumb/5/50/RedPandaFullBody.JPG/1200px-RedPandaFullBody.JPG']

# %%
dest = 'images/red.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F65B4CB3700>

# %%
bear_types = 'red','giant','we bare bears'
path = Path('panda')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} panda')
        download_images(dest, urls=results.attrgot('contentUrl'))
# Out:
#  Download of https://eattravelhappy.files.wordpress.com/2013/01/dsc04487-e.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p panda/red
# $ cd panda/red
# $ wget -c https://eattravelhappy.files.wordpress.com/2013/01/dsc04487-e.jpg
# $ tar xf dsc04487-e.jpg
#  And re-run your code once the download is successful
#
#
#  Download of https://illuminatebytanya.files.wordpress.com/2013/06/redpandanetworkorg.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p panda/red
# $ cd panda/red
# $ wget -c https://illuminatebytanya.files.wordpress.com/2013/06/redpandanetworkorg.jpg
# $ tar xf redpandanetworkorg.jpg
#  And re-run your code once the download is successful
#
#
#  Download of https://redpanda08.files.wordpress.com/2013/09/female-red.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p panda/red
# $ cd panda/red
# $ wget -c https://redpanda08.files.wordpress.com/2013/09/female-red.jpg
# $ tar xf female-red.jpg
# ...

# %%
fns = get_image_files(path)
fns
# Out:
# (#444) [Path('panda/red/00000002.jpg'),Path('panda/red/00000007.jpg'),Path('panda/red/00000005.jpg'),Path('panda/red/00000008.jpg'),Path('panda/red/00000009.jpg'),Path('panda/red/00000012.jpg'),Path('panda/red/00000011.jpg'),Path('panda/red/00000004.jpg'),Path('panda/red/00000000.JPG'),Path('panda/red/00000014.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#13) [Path('panda/red/00000004.jpg'),Path('panda/red/00000015.JPG'),Path('panda/red/00000048.jpg'),Path('panda/red/00000144.jpg'),Path('panda/giant/00000001.jpg'),Path('panda/giant/00000010.jpg'),Path('panda/giant/00000028.jpg'),Path('panda/giant/00000095.jpg'),Path('panda/giant/00000098.jpg'),Path('panda/giant/00000100.jpg')...]

# %%
failed.map(Path.unlink);

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.191722</td>
#       <td>0.071634</td>
#       <td>0.011628</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/envs/fastai/lib/python3.8/site-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# ...

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/red.jpg')
# Out:
# ('red', TensorImage(1), TensorImage([2.1478e-06, 1.0000e+00, 7.7402e-07]))

# %%
learn_inf.dls.vocab
# Out:
# ['giant', 'red', 'we bare bears']

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/red.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: red; Probability: 1.0000')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your panda!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
